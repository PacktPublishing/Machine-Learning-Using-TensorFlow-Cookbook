# %% [markdown]
# # Linear Regression

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Learning the TensorFlow way of linear regression

# %%
import numpy as np
import pandas as pd
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

housing_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
path = tf.keras.utils.get_file(housing_url.split("/")[-1], housing_url)

columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_table(path, delim_whitespace=True, header=None, names=columns)

np.random.seed(1)
train = data.sample(frac=0.8).copy()
y_train = train['MEDV']
train.drop('MEDV', axis=1, inplace=True)

test = data.loc[~data.index.isin(train.index)].copy()
y_test = test['MEDV']
test.drop('MEDV', axis=1, inplace=True)

# %%
def define_feature_columns(data_df, categorical_cols, numeric_cols):
    feature_columns = []
    
    for feature_name in numeric_cols:
        feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))
    
    for feature_name in categorical_cols:
        vocabulary = data_df[feature_name].unique()
        feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

    return feature_columns

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=256):
    
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    
    return input_function

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns = define_feature_columns(data, categorical_cols, numeric_cols)

train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

# %%
linear_est = tf.estimator.LinearRegressor(feature_columns=feature_columns)
linear_est.train(train_input_fn)
result = linear_est.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdm_nc8o_
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpdm_nc8o_', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /home/lm/anaconda3/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/lm/anaconda3/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From /home/lm/anaconda3/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:540: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /home/lm/anaconda3/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/keras/optimizer_v2/ftrl.py:144: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpdm_nc8o_/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 566.9584, step = 0
# INFO:tensorflow:global_step/sec: 340.218
# INFO:tensorflow:loss = 62.017567, step = 100 (0.294 sec)
# INFO:tensorflow:global_step/sec: 545.378
# INFO:tensorflow:loss = 53.471813, step = 200 (0.184 sec)
# INFO:tensorflow:global_step/sec: 549.545
# INFO:tensorflow:loss = 53.426826, step = 300 (0.182 sec)
# INFO:tensorflow:global_step/sec: 572.513
# INFO:tensorflow:loss = 44.331467, step = 400 (0.175 sec)
# INFO:tensorflow:global_step/sec: 553.826
# INFO:tensorflow:loss = 39.06472, step = 500 (0.181 sec)
# INFO:tensorflow:global_step/sec: 551.077
# INFO:tensorflow:loss = 37.099564, step = 600 (0.182 sec)
# INFO:tensorflow:global_step/sec: 549.982
# INFO:tensorflow:loss = 37.535316, step = 700 (0.182 sec)
# INFO:tensorflow:global_step/sec: 553.108
# INFO:tensorflow:loss = 45.019566, step = 800 (0.181 sec)
# INFO:tensorflow:global_step/sec: 556.732
# INFO:tensorflow:loss = 36.494034, step = 900 (0.180 sec)
# INFO:tensorflow:global_step/sec: 558.375
# INFO:tensorflow:loss = 38.498, step = 1000 (0.179 sec)
# INFO:tensorflow:global_step/sec: 555.227
# INFO:tensorflow:loss = 37.191967, step = 1100 (0.180 sec)
# INFO:tensorflow:global_step/sec: 571.651
# INFO:tensorflow:loss = 36.252747, step = 1200 (0.175 sec)
# INFO:tensorflow:global_step/sec: 578.01
# INFO:tensorflow:loss = 35.085556, step = 1300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 515.52
# INFO:tensorflow:loss = 33.238483, step = 1400 (0.194 sec)
# INFO:tensorflow:global_step/sec: 559.706
# INFO:tensorflow:loss = 31.409883, step = 1500 (0.179 sec)
# INFO:tensorflow:global_step/sec: 560.344
# INFO:tensorflow:loss = 34.272392, step = 1600 (0.178 sec)
# INFO:tensorflow:global_step/sec: 555.582
# INFO:tensorflow:loss = 40.610798, step = 1700 (0.180 sec)
# INFO:tensorflow:global_step/sec: 575.372
# INFO:tensorflow:loss = 32.52101, step = 1800 (0.174 sec)
# INFO:tensorflow:global_step/sec: 553.645
# INFO:tensorflow:global_step/sec: 524.869
# INFO:tensorflow:loss = 36.651543, step = 4200 (0.190 sec)
# INFO:tensorflow:global_step/sec: 532.988
# INFO:tensorflow:loss = 27.76774, step = 4300 (0.188 sec)
# INFO:tensorflow:global_step/sec: 551.214
# INFO:tensorflow:loss = 23.367308, step = 4400 (0.181 sec)
# INFO:tensorflow:global_step/sec: 542.2
# INFO:tensorflow:loss = 28.126688, step = 4500 (0.184 sec)
# INFO:tensorflow:global_step/sec: 554.608
# INFO:tensorflow:loss = 28.572132, step = 4600 (0.180 sec)
# INFO:tensorflow:global_step/sec: 555.616
# INFO:tensorflow:loss = 27.02995, step = 4700 (0.180 sec)
# INFO:tensorflow:global_step/sec: 515.905
# INFO:tensorflow:loss = 26.29895, step = 4800 (0.194 sec)
# INFO:tensorflow:global_step/sec: 553.524
# INFO:tensorflow:loss = 30.686684, step = 4900 (0.181 sec)
# INFO:tensorflow:global_step/sec: 591.134
# INFO:tensorflow:loss = 27.0451, step = 5000 (0.169 sec)
# INFO:tensorflow:global_step/sec: 586.34
# INFO:tensorflow:loss = 26.976416, step = 5100 (0.170 sec)
# INFO:tensorflow:global_step/sec: 575.402
# INFO:tensorflow:loss = 25.412128, step = 5200 (0.174 sec)
# INFO:tensorflow:global_step/sec: 595.303
# INFO:tensorflow:loss = 21.907635, step = 5300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 589.645
# INFO:tensorflow:loss = 25.743153, step = 5400 (0.169 sec)
# INFO:tensorflow:global_step/sec: 593.972
# INFO:tensorflow:loss = 27.121698, step = 5500 (0.169 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5600...
# INFO:tensorflow:Saving checkpoints for 5600 into /tmp/tmpdm_nc8o_/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5600...
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdm_nc8o_/model.ckpt-5600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.33831s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:04
# INFO:tensorflow:Saving dict for global step 5600: average_loss = 30.94743, global_step = 5600, label/mean = 22.048517, loss = 30.94743, prediction/mean = 20.699535
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5600: /tmp/tmpdm_nc8o_/model.ckpt-5600
# INFO:tensorflow:Loss for final step: 19.389862.

# %%
history
# Out:
# ({'average_loss': 30.94743,
#   'label/mean': 22.048517,
#   'loss': 30.94743,
#   'prediction/mean': 20.699535,
#   'global_step': 5600},
#  [])

# %% [markdown]
# ### Interactions

# %%
def create_interactions(interactions_list, buckets=5):
    interactions = list()
    for (a, b) in interactions_list:
        interactions.append(tf.feature_column.crossed_column([a, b], hash_bucket_size=buckets))
    return interactions

derived_feature_columns = create_interactions([['RM', 'LSTAT']])
linear_est = tf.estimator.LinearRegressor(feature_columns=feature_columns+derived_feature_columns)
linear_est.train(train_input_fn)
result = linear_est.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpw_hyg0xs
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpw_hyg0xs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpw_hyg0xs/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss =

# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpw_hyg0xs/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [[25.08104  ]
#  [30.736357 ]
#  [20.4524   ]
#  [22.03055  ]
#  [18.398361 ]
#  [17.318958 ]
#  [18.694675 ]
#  [12.970281 ]
#  [23.9705   ]
#  [25.51155  ]
#  [21.133453 ]
#  [17.561405 ]
#  [28.958225 ]
#  [17.340523 ]
#  [20.158869 ]
#  [21.370161 ]
#  [24.527313 ]
#  [23.350826 ]
#  [25.059666 ]
#  [22.908648 ]
#  [26.708612 ]
#  [25.697247 ]
#  [23.403347 ]
#  [19.854527 ]
#  [21.335016 ]
#  [12.041699 ]
#  [17.918808 ]
#  [21.868622 ]
#  [20.758556 ]
#  [ 6.256716 ]
#  [13.554651 ]
#  [10.597319 ]
#  [20.23985  ]
#  [19.312706 ]
#  [15.588332 ]
#  [34.098156 ]
#  [28.005566 ]
#  [29.337234 ]
#  [34.536808 ]
#  [34.30555  ]
#  [35.28596  ]
#  [15.942515 ]
#  [20.577133 ]
#  [24.189905 ]
#  [36.664703 ]
#  [26.498766 ]
#  [32.747536 ]
#  [25.06283  ]
#  [20.710165 ]
#  [23.050678 ]
#  [27.6707   ]
#  [25.15589  ]
#  [24.369576 ]
#  [30.670273 ]
#  [24.002787 ]
#  [24.098145 ]
#  [33.417355 ]
#  [28.075247 ]
#  [33.283237 ]
#  [28.120035 ]
#  [36.21954  ]
#  [26.085346 ]
#  [16.128317 ]
#  [26.868885 ]
#  [25.100857 ]
#  [15.926276 ]
#  [18.670334 ]
#  [19.249226 ]
#  [23.689404 ]
#  [24.82412  ]
#  [27.864616 ]
#  [23.295496 ]
#  [23.440811 ]
#  [26.829603 ]
#  [13.480348 ]
#  [25.17673  ]
#  [19.884987 ]
#  [ 5.144221 ]
#  [ 7.1226525]
#  [21.272936 ]
#  [19.200989 ]
#  [21.4528   ]
#  [20.951317 ]
#  [21.140789 ]
#  [ 8.424867 ]
#  [18.2235   ]
#  [12.302758 ]
#  [13.098577 ]
#  [ 8.870223 ]
#  [14.969712 ]
#  [20.624828 ]
#  [18.637848 ]
#  [21.385662 ]
#  [18.258913 ]
#  [16.768908 ]
#  [20.037933 ]
#  [22.668255 ]
#  [13.494691 ]
#  [21.989395 ]
#  [14.051217 ]
#  [20.01759  ]]

# %% [markdown]
# ### Keras to estimator version

# %%
import tensorflow.keras as keras

# %%
def define_feature_columns_layers(data_df, categorical_cols, numeric_cols):
    feature_columns = []
    feature_layer_inputs = {}
    
    for feature_name in numeric_cols:
        feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))
        feature_layer_inputs[feature_name] = tf.keras.Input(shape=(1,), name=feature_name)
        
    for feature_name in categorical_cols:
        vocabulary = data_df[feature_name].unique()
        cat = tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary)
        cat_one_hot = tf.feature_column.indicator_column(cat)
        feature_columns.append(cat_one_hot)
        feature_layer_inputs[feature_name] = tf.keras.Input(shape=(1,), name=feature_name, dtype=tf.int32)
    
    return feature_columns, feature_layer_inputs

# %%
def create_interactions(interactions_list, buckets=5):
    feature_columns = []
    
    for (a, b) in interactions_list:
        crossed_feature = tf.feature_column.crossed_column([a, b], hash_bucket_size=buckets)
        crossed_feature_one_hot = tf.feature_column.indicator_column(crossed_feature)
        feature_columns.append(crossed_feature_one_hot)
        
    return feature_columns

# %%
def create_linreg(feature_columns, feature_layer_inputs, optimizer):

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, kernel_initializer='normal', activation='linear')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)
interactions_columns = create_interactions([['RM', 'LSTAT']])

feature_columns += interactions_columns

optimizer = keras.optimizers.Ftrl(learning_rate=0.02)
model = create_linreg(feature_columns, feature_layer_inputs, optimizer)

# %%
import tempfile

def canned_keras(model):
    model_dir = tempfile.mkdtemp()
    keras_estimator = tf.keras.estimator.model_to_estimator(
        keras_model=model, model_dir=model_dir)
    return keras_estimator

estimator = canned_keras(model)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpirpz5263', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmpirpz5263/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmpirpz5263/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpirpz5263/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 606.54675, step = 0
# INFO:tensorflow:global_step/sec: 416.489
# INFO:tensorflow:loss = 286.50177, step = 100 (0.241 sec)
# INFO:tensorflow:global_step/sec: 572.532
# INFO:tensorflow:loss = 136.93703, step = 200 (0.175 sec)
# INFO:tensorflow:global_step/sec: 579.724
# INFO:tensorflow:loss = 74.51466, step = 300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 583.277
# INFO:tensorflow:loss = 49.7192, step = 400 (0.171 sec)
# INFO:tensorflow:global_step/sec: 584.73
# INFO:tensorflow:loss = 47.10332, step = 500 (0.171 sec)
# INFO:tensorflow:global_step/sec: 577.956
# INFO:tensorflow:loss = 35.021683, step = 600 (0.173 sec)
# INFO:tensorflow:global_step/sec: 584.228
# INFO:tensorflow:loss = 27.665234, step = 700 (0.171 sec)
# INFO:tensorflow:global_step/sec: 578.255
# INFO:tensorflow:loss = 33.317642, step = 800 (0.173 sec)
# INFO:tensorflow:global_step/sec: 583.5
# INFO:tensorflow:loss = 37.01431, step = 900 (0.171 sec)
# INFO:tensorflow:global_step/sec: 569.584
# INFO:tensorflow:loss = 38.39798, step = 1000 (0.176 sec)
# INFO:tensorflow:global_step/sec: 572.129
# INFO:tensorflow:loss = 30.786415, step = 1100 (0.175 sec)
# INFO:tensorflow:global_step/sec: 569.698
# INFO:tensorflow:loss = 29.134235, step = 1200 (0.175 sec)
# INFO:tensorflow:global_step/sec: 561.93
# INFO:tensorflow:loss = 32.173096, step = 1300 (0.178 sec)
# INFO:tensorflow:global_step/sec: 551.717
# INFO:tensorflow:loss = 32.180367, step = 1400 (0.181 sec)
# INFO:tensorflow:global_step/sec: 521.547
# INFO:tensorflow:loss = 31.619564, step = 1500 (0.192 sec)
# INFO:tensorflow:global_step/sec: 526.02
# INFO:tensorflow:loss = 25.76949, step = 1600 (0.190 sec)
# INFO:tensorflow:global_step/sec: 580.123
# INFO:tensorflow:loss = 28.921408, step = 1700 (0.173 sec)
# INFO:tensorflow:global_step/sec: 523.367
# INFO:tensorflow:loss = 25.11536, step = 1800 (0.191 sec)
# INFO:tensorflow:global_step/sec: 529.929
# INFO:tensorflow:loss = 22.91909, step = 1900 (0.189 sec)
# INFO:tensorflow:global_step/sec: 536.091
# INFO:tensorflow:loss = 24.68335, step = 2000 (0.187 sec)
# INFO:tensorflow:global_step/sec: 512.246
# INFO:tensorflow:loss = 18.364576, step = 2100 (0.195 sec)
# INFO:tensorflow:global_step/sec: 550.024
# INFO:tensorflow:loss = 23.092136, step = 2200 (0.182 sec)
# INFO:tensorflow:global_step/sec: 584.645
# INFO:tensorflow:loss = 27.682545, step = 2300 (0.171 sec)
# INFO:tensorflow:global_step/sec: 586.52
# INFO:tensorflow:loss = 22.707008, step = 2400 (0.170 sec)
# INFO:tensorflow:global_step/sec: 566.671
# INFO:tensorflow:loss = 22.329357, step = 2500 (0.177 sec)
# INFO:tensorflow:global_step/sec: 568.388
# INFO:tensorflow:loss = 24.946896, step = 2600 (0.176 sec)
# INFO:tensorflow:global_step/sec: 572.548
# INFO:tensorflow:loss = 25.234146, step = 2700 (0.175 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmpirpz5263/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 27.659222.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpirpz5263/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.13891s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:21
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 25.583979
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmpirpz5263/model.ckpt-2800
# {'loss': 25.583979, 'global_step': 2800}

# %% [markdown]
# ## Understanding coefficients in linear regression

# %%
weights = estimator.get_variable_value('layer_with_weights-1/kernel/.ATTRIBUTES/VARIABLE_VALUE')

# %%
print(weights)
# Out:
# [[-0.8490454 ]
#  [ 0.8686714 ]
#  [-0.8428856 ]
#  [ 0.8511777 ]
#  [-0.8376383 ]
#  [ 1.1389176 ]
#  [-0.78909713]
#  [-1.2872502 ]
#  [ 0.8498743 ]
#  [-0.8803969 ]
#  [ 0.8877582 ]
#  [ 0.87467986]
#  [-0.9110018 ]
#  [-0.8250329 ]
#  [ 1.0101635 ]
#  [-0.916412  ]
#  [ 0.8828062 ]
#  [ 0.8920506 ]
#  [-0.8579407 ]
#  [ 0.8726998 ]
#  [ 0.83079267]
#  [ 0.8901703 ]
#  [ 0.9014009 ]
#  [-0.7936326 ]
#  [ 1.3419524 ]
#  [ 0.7849937 ]
#  [ 0.88007724]]

# %%
def extract_labels(feature_columns):
    labels = list()
    for col in feature_columns:
        col_config = col.get_config()
        if 'key' in col_config:
            labels.append(col_config['key'])
        elif 'categorical_column' in col_config:
            if col_config['categorical_column']['class_name']=='VocabularyListCategoricalColumn':
                key = col_config['categorical_column']['config']['key']
                for item in col_config['categorical_column']['config']['vocabulary_list']:
                     labels.append(key+'_val='+str(item))
            elif col_config['categorical_column']['class_name']=='CrossedColumn':
                keys = col_config['categorical_column']['config']['keys']
                for bucket in range(col_config['categorical_column']['config']['hash_bucket_size']):
                    labels.append('x'.join(keys)+'_bkt_'+str(bucket))
    return labels

# %%
labels = extract_labels(feature_columns)

for label, weight in zip(labels, weights):
    print(f"{label:15s} : {weight[0]:+.2f}")
# Out:
# CRIM            : -0.85
# ZN              : +0.87
# INDUS           : -0.84
# NOX             : +0.85
# RM              : -0.84
# AGE             : +1.14
# DIS             : -0.79
# TAX             : -1.29
# PTRATIO         : +0.85
# B               : -0.88
# LSTAT           : +0.89
# CHAS_val=0      : +0.87
# CHAS_val=1      : -0.91
# RAD_val=1       : -0.83
# RAD_val=2       : +1.01
# RAD_val=3       : -0.92
# RAD_val=5       : +0.88
# RAD_val=4       : +0.89
# RAD_val=8       : -0.86
# RAD_val=6       : +0.87
# RAD_val=7       : +0.83
# RAD_val=24      : +0.89
# RMxLSTAT_bkt_0  : +0.90
# RMxLSTAT_bkt_1  : -0.79
# RMxLSTAT_bkt_2  : +1.34
# RMxLSTAT_bkt_3  : +0.78
# RMxLSTAT_bkt_4  : +0.88

# %% [markdown]
# ## Understanding loss functions in linear regression

# %%
def create_linreg(feature_columns, feature_layer_inputs, optimizer, 
                  loss='mean_squared_error', metrics=['mean_absolute_error']):

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, kernel_initializer='normal', activation='linear')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)
interactions_columns = create_interactions([['RM', 'LSTAT']])

feature_columns += interactions_columns

optimizer = keras.optimizers.Ftrl(learning_rate=0.02)
model = create_linreg(feature_columns, feature_layer_inputs, optimizer,
                      loss='mean_absolute_error', 
                      metrics=['mean_absolute_error', 'mean_squared_error'])

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp_77yg3dd', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmp_77yg3dd/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmp_77yg3dd/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp_77yg3dd/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 22.360157, step = 0
# INFO:tensorflow:global_step/sec: 390.743
# INFO:tensorflow:loss = 21.049074, step = 100 (0.257 sec)
# INFO:tensorflow:global_step/sec: 497.984
# INFO:tensorflow:loss = 14.785265, step = 200 (0.201 sec)
# INFO:tensorflow:global_step/sec: 527.459
# INFO:tensorflow:loss = 7.4517565, step = 300 (0.190 sec)
# INFO:tensorflow:global_step/sec: 525.516
# INFO:tensorflow:loss = 4.9231777, step = 400 (0.190 sec)
# INFO:tensorflow:global_step/sec: 508.911
# INFO:tensorflow:loss = 4.291701, step = 500 (0.196 sec)
# INFO:tensorflow:global_step/sec: 529.019
# INFO:tensorflow:loss = 3.8679302, step = 600 (0.189 sec)
# INFO:tensorflow:global_step/sec: 533.335
# INFO:tensorflow:loss = 3.4416203, step = 700 (0.188 sec)
# INFO:tensorflow:global_step/sec: 529.254
# INFO:tensorflow:loss = 3.4997668, step = 800 (0.189 sec)
# INFO:tensorflow:global_step/sec: 534.506
# INFO:tensorflow:loss = 3.8724923, step = 900 (0.187 sec)
# INFO:tensorflow:global_step/sec: 522.479
# INFO:tensorflow:loss = 3.7194963, step = 1000 (0.191 sec)
# INFO:tensorflow:global_step/sec: 568.913
# INFO:tensorflow:loss = 3.646995, step = 1100 (0.176 sec)
# INFO:tensorflow:global_step/sec: 580.316
# INFO:tensorflow:loss = 3.9428349, step = 1200 (0.172 sec)
# INFO:tensorflow:global_step/sec: 581.872
# INFO:tensorflow:loss = 3.5306451, step = 1300 (0.172 sec)
# INFO:tensorflow:global_step/sec: 583.291
# INFO:tensorflow:loss = 3.4062629, step = 1400 (0.171 sec)
# INFO:tensorflow:global_step/sec: 582.519
# INFO:tensorflow:loss = 3.0022087, step = 1500 (0.172 sec)
# INFO:tensorflow:global_step/sec: 578.838
# INFO:tensorflow:loss = 3.2101576, step = 1600 (0.173 sec)
# INFO:tensorflow:global_step/sec: 581.222
# INFO:tensorflow:loss = 3.249371, step = 1700 (0.172 sec)
# INFO:tensorflow:global_step/sec: 579.757
# INFO:tensorflow:loss = 3.1928504, step = 1800 (0.172 sec)
# INFO:tensorflow:global_step/sec: 579.689
# INFO:tensorflow:loss = 3.3453884, step = 1900 (0.172 sec)
# INFO:tensorflow:global_step/sec: 577.959
# INFO:tensorflow:loss = 3.1577191, step = 2000 (0.173 sec)
# INFO:tensorflow:global_step/sec: 581.018
# INFO:tensorflow:loss = 3.1438386, step = 2100 (0.172 sec)
# INFO:tensorflow:global_step/sec: 584.749
# INFO:tensorflow:loss = 3.2384605, step = 2200 (0.171 sec)
# INFO:tensorflow:global_step/sec: 562.865
# INFO:tensorflow:loss = 2.9923697, step = 2300 (0.178 sec)
# INFO:tensorflow:global_step/sec: 568.974
# INFO:tensorflow:loss = 3.0170753, step = 2400 (0.176 sec)
# INFO:tensorflow:global_step/sec: 570.073
# INFO:tensorflow:loss = 3.1158519, step = 2500 (0.175 sec)
# INFO:tensorflow:global_step/sec: 569.146
# INFO:tensorflow:loss = 2.905593, step = 2600 (0.176 sec)
# INFO:tensorflow:global_step/sec: 563.576
# INFO:tensorflow:loss = 3.1256428, step = 2700 (0.178 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmp_77yg3dd/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 3.8812757.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp_77yg3dd/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.14372s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:28
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 3.1180813, mean_absolute_error = 3.1180813, mean_squared_error = 27.18468
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmp_77yg3dd/model.ckpt-2800
# {'loss': 3.1180813, 'mean_absolute_error': 3.1180813, 'mean_squared_error': 27.18468, 'global_step': 2800}

# %% [markdown]
# ## Implementing lasso and ridge regression

# %%
def create_ridge_linreg(feature_columns, feature_layer_inputs, optimizer, 
                        loss='mean_squared_error', metrics=['mean_absolute_error'],
                        l2=0.01):
    
    regularizer = keras.regularizers.l2(l2)

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, 
                                 kernel_initializer='normal', 
                                 kernel_regularizer = regularizer, 
                                 activation='linear')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)
interactions_columns = create_interactions([['RM', 'LSTAT']])

feature_columns += interactions_columns

optimizer = keras.optimizers.Ftrl(learning_rate=0.02)
model = create_ridge_linreg(feature_columns, feature_layer_inputs, optimizer,
                      loss='mean_squared_error', 
                      metrics=['mean_absolute_error', 'mean_squared_error'],
                           l2=0.01)

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpq2zk8iqe', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmpq2zk8iqe/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmpq2zk8iqe/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpq2zk8iqe/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 610.0148, step = 0
# INFO:tensorflow:global_step/sec: 416.976
# INFO:tensorflow:loss = 311.63828, step = 100 (0.241 sec)
# INFO:tensorflow:global_step/sec: 586.021
# INFO:tensorflow:loss = 125.290245, step = 200 (0.171 sec)
# INFO:tensorflow:global_step/sec: 577.446
# INFO:tensorflow:loss = 75.893555, step = 300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 559.248
# INFO:tensorflow:loss = 43.239006, step = 400 (0.179 sec)
# INFO:tensorflow:global_step/sec: 541.904
# INFO:tensorflow:loss = 40.05228, step = 500 (0.184 sec)
# INFO:tensorflow:global_step/sec: 549.02
# INFO:tensorflow:loss = 32.282825, step = 600 (0.182 sec)
# INFO:tensorflow:global_step/sec: 547.203
# INFO:tensorflow:loss = 37.50748, step = 700 (0.183 sec)
# INFO:tensorflow:global_step/sec: 534.393
# INFO:tensorflow:loss = 29.994751, step = 800 (0.187 sec)
# INFO:tensorflow:global_step/sec: 523.394
# INFO:tensorflow:loss = 21.398178, step = 900 (0.191 sec)
# INFO:tensorflow:global_step/sec: 508.122
# INFO:tensorflow:loss = 29.010948, step = 1000 (0.197 sec)
# INFO:tensorflow:global_step/sec: 535.2
# INFO:tensorflow:loss = 30.861378, step = 1100 (0.187 sec)
# INFO:tensorflow:global_step/sec: 510.49
# INFO:tensorflow:loss = 24.097967, step = 1200 (0.196 sec)
# INFO:tensorflow:global_step/sec: 494.969
# INFO:tensorflow:loss = 26.508583, step = 1300 (0.202 sec)
# INFO:tensorflow:global_step/sec: 474.209
# INFO:tensorflow:loss = 26.133356, step = 1400 (0.211 sec)
# INFO:tensorflow:global_step/sec: 469.452
# INFO:tensorflow:loss = 24.072468, step = 1500 (0.215 sec)
# INFO:tensorflow:global_step/sec: 499.259
# INFO:tensorflow:loss = 20.323114, step = 1600 (0.199 sec)
# INFO:tensorflow:global_step/sec: 466.212
# INFO:tensorflow:loss = 30.543634, step = 1700 (0.215 sec)
# INFO:tensorflow:global_step/sec: 516.927
# INFO:tensorflow:loss = 26.54226, step = 1800 (0.193 sec)
# INFO:tensorflow:global_step/sec: 528.167
# INFO:tensorflow:loss = 29.535326, step = 1900 (0.189 sec)
# INFO:tensorflow:global_step/sec: 546.395
# INFO:tensorflow:loss = 20.94144, step = 2000 (0.184 sec)
# INFO:tensorflow:global_step/sec: 555.391
# INFO:tensorflow:loss = 25.32218, step = 2100 (0.180 sec)
# INFO:tensorflow:global_step/sec: 565.499
# INFO:tensorflow:loss = 26.085375, step = 2200 (0.177 sec)
# INFO:tensorflow:global_step/sec: 557.097
# INFO:tensorflow:loss = 27.256327, step = 2300 (0.180 sec)
# INFO:tensorflow:global_step/sec: 549.849
# INFO:tensorflow:loss = 24.119463, step = 2400 (0.182 sec)
# INFO:tensorflow:global_step/sec: 562.994
# INFO:tensorflow:loss = 26.963236, step = 2500 (0.178 sec)
# INFO:tensorflow:global_step/sec: 564.045
# INFO:tensorflow:loss = 25.808764, step = 2600 (0.177 sec)
# INFO:tensorflow:global_step/sec: 568.073
# INFO:tensorflow:loss = 20.972824, step = 2700 (0.176 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmpq2zk8iqe/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 25.642887.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpq2zk8iqe/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.15511s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:36
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 25.292578, mean_absolute_error = 3.2190397, mean_squared_error = 25.065119
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmpq2zk8iqe/model.ckpt-2800
# {'loss': 25.292578, 'mean_absolute_error': 3.2190397, 'mean_squared_error': 25.065119, 'global_step': 2800}

# %%
def create_lasso_linreg(feature_columns, feature_layer_inputs, optimizer, 
                        loss='mean_squared_error', metrics=['mean_absolute_error'],
                        l1=0.001):
    
    regularizer = keras.regularizers.l1(l1)

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, 
                                 kernel_initializer='normal', 
                                 kernel_regularizer = regularizer, 
                                 activation='linear')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)
interactions_columns = create_interactions([['RM', 'LSTAT']])

feature_columns += interactions_columns

optimizer = keras.optimizers.Ftrl(learning_rate=0.02)
model = create_lasso_linreg(feature_columns, feature_layer_inputs, optimizer,
                      loss='mean_squared_error', 
                      metrics=['mean_absolute_error', 'mean_squared_error'],
                           l1=0.001)

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmps8vwki_f', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmps8vwki_f/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmps8vwki_f/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/t
sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmps8vwki_f/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 27.683546.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmps8vwki_f/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.14893s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:44
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 24.427715, mean_absolute_error = 3.1783547, mean_squared_error = 24.402922
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmps8vwki_f/model.ckpt-2800
# {'loss': 24.427715, 'mean_absolute_error': 3.1783547, 'mean_squared_error': 24.402922, 'global_step': 2800}

# %% [markdown]
# ## Implementing elastic net regression

# %%
def create_elasticnet_linreg(feature_columns, feature_layer_inputs, optimizer, 
                        loss='mean_squared_error', metrics=['mean_absolute_error'],
                        l1=0.001, l2=0.01):
    
    regularizer = keras.regularizers.l1_l2(l1=l1, l2=l2)

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, 
                                 kernel_initializer='normal', 
                                 kernel_regularizer = regularizer, 
                                 activation='linear')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = ['CHAS', 'RAD']
numeric_cols = ['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)
interactions_columns = create_interactions([['RM', 'LSTAT']])

feature_columns += interactions_columns

optimizer = keras.optimizers.Ftrl(learning_rate=0.02)
model = create_elasticnet_linreg(feature_columns, feature_layer_inputs, optimizer,
                      loss='mean_squared_error', 
                      metrics=['mean_absolute_error', 'mean_squared_error'],
                           l1=0.001, l2=0.01)

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=1400)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpvfp1it63', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmpvfp1it63/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmpvfp1it63/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpvfp1it63/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 616.7669, step = 0
# INFO:tensorflow:global_step/sec: 368.413
# INFO:tensorflow:loss = 312.5437, step = 100 (0.272 sec)
# INFO:tensorflow:global_step/sec: 548.651
# INFO:tensorflow:loss = 142.78972, step = 200 (0.182 sec)
# INFO:tensorflow:global_step/sec: 536.316
# INFO:tensorflow:loss = 57.095, step = 300 (0.186 sec)
# INFO:tensorflow:global_step/sec: 496.317
# INFO:tensorflow:loss = 43.478172, step = 400 (0.202 sec)
# INFO:tensorflow:global_step/sec: 535.177
# INFO:tensorflow:loss = 36.115498, step = 500 (0.187 sec)
# INFO:tensorflow:global_step/sec: 512.73
# INFO:tensorflow:loss = 34.258068, step = 600 (0.195 sec)
# INFO:tensorflow:global_step/sec: 516.623
# INFO:tensorflow:loss = 29.993673, step = 700 (0.193 sec)
# INFO:tensorflow:global_step/sec: 542.409
# INFO:tensorflow:loss = 27.524889, step = 800 (0.184 sec)
# INFO:tensorflow:global_step/sec: 546.919
# INFO:tensorflow:loss = 32.03893, step = 900 (0.183 sec)
# INFO:tensorflow:global_step/sec: 545.667
# INFO:tensorflow:loss = 25.89037, step = 1000 (0.183 sec)
# INFO:tensorflow:global_step/sec: 511.749
# INFO:tensorflow:loss = 25.044495, step = 1100 (0.195 sec)
# INFO:tensorflow:global_step/sec: 537.049
# INFO:tensorflow:loss = 25.749477, step = 1200 (0.186 sec)
# INFO:tensorflow:global_step/sec: 496.167
# INFO:tensorflow:loss = 27.83967, step = 1300 (0.202 sec)
# INFO:tensorflow:global_step/sec: 535.681
# INFO:tensorflow:loss = 26.843252, step = 1400 (0.186 sec)
# INFO:tensorflow:global_step/sec: 570.244
# INFO:tensorflow:loss = 29.432669, step = 1500 (0.175 sec)
# INFO:tensorflow:global_step/sec: 545.887
# INFO:tensorflow:loss = 26.346788, step = 1600 (0.183 sec)
# INFO:tensorflow:global_step/sec: 545.729
# INFO:tensorflow:loss = 27.233725, step = 1700 (0.183 sec)
# INFO:tensorflow:global_step/sec: 548.851
# INFO:tensorflow:loss = 23.024546, step = 1800 (0.182 sec)
# INFO:tensorflow:global_step/sec: 548.332
# INFO:tensorflow:loss = 29.620409, step = 1900 (0.182 sec)
# INFO:tensorflow:global_step/sec: 552.014
# INFO:tensorflow:loss = 23.481886, step = 2000 (0.181 sec)
# INFO:tensorflow:global_step/sec: 543.356
# INFO:tensorflow:loss = 27.36317, step = 2100 (0.184 sec)
# INFO:tensorflow:global_step/sec: 521.891
# INFO:tensorflow:loss = 26.85298, step = 2200 (0.191 sec)
# INFO:tensorflow:global_step/sec: 492.055
# INFO:tensorflow:loss = 18.450066, step = 2300 (0.203 sec)
# INFO:tensorflow:global_step/sec: 504.392
# INFO:tensorflow:loss = 19.9276, step = 2400 (0.198 sec)
# INFO:tensorflow:global_step/sec: 532.608
# INFO:tensorflow:loss = 21.555618, step = 2500 (0.188 sec)
# INFO:tensorflow:global_step/sec: 533.871
# INFO:tensorflow:loss = 21.984354, step = 2600 (0.187 sec)
# INFO:tensorflow:global_step/sec: 545.321
# INFO:tensorflow:loss = 23.516447, step = 2700 (0.183 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2800...
# INFO:tensorflow:Saving checkpoints for 2800 into /tmp/tmpvfp1it63/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2800...
# INFO:tensorflow:Loss for final step: 18.934238.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvfp1it63/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.14610s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:51
# INFO:tensorflow:Saving dict for global step 2800: global_step = 2800, loss = 24.910872, mean_absolute_error = 3.208289, mean_squared_error = 24.659771
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: /tmp/tmpvfp1it63/model.ckpt-2800
# {'loss': 24.910872, 'mean_absolute_error': 3.208289, 'mean_squared_error': 24.659771, 'global_step': 2800}

# %% [markdown]
# ## Implementing logistic regression

# %%
breast_cancer = 'https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data'
path = tf.keras.utils.get_file(breast_cancer.split("/")[-1], breast_cancer)

columns = ['sample_code', 'clump_thickness', 'cell_size_uniformity', 'cell_shape_uniformity',
           'marginal_adhesion', 'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin',
           'normal_nucleoli', 'mitoses', 'class']

data = pd.read_csv(path, header=None, names=columns, na_values=[np.nan, '?'])
data = data.fillna(data.median())

np.random.seed(1)
train = data.sample(frac=0.8).copy()
y_train = (train['class']==4).astype(int)
train.drop(['sample_code', 'class'], axis=1, inplace=True)

test = data.loc[~data.index.isin(train.index)].copy()
y_test = (test['class']==4).astype(int)
test.drop(['sample_code', 'class'], axis=1, inplace=True)

# %%
def create_logreg(feature_columns, feature_layer_inputs, optimizer, 
                  loss='binary_crossentropy', metrics=['accuracy'],
                  l2=0.01):
    
    regularizer = keras.regularizers.l2(l2)

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    outputs = keras.layers.Dense(1, 
                                 kernel_initializer='normal', 
                                 kernel_regularizer = regularizer, 
                                 activation='sigmoid')(norm)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = []
numeric_cols = ['clump_thickness', 'cell_size_uniformity', 'cell_shape_uniformity',
                'marginal_adhesion', 'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin',
                'normal_nucleoli', 'mitoses']

feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)

optimizer = keras.optimizers.Ftrl(learning_rate=0.007)
model = create_logreg(feature_columns, feature_layer_inputs, optimizer, l2=0.01)

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=300, batch_size=32)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpkgcln5d7', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmpkgcln5d7/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmpkgcln5d7/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 4 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpkgcln5d7/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0
(0.083 sec)
# INFO:tensorflow:global_step/sec: 1253.46
# INFO:tensorflow:loss = 0.113034844, step = 4800 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1244.43
# INFO:tensorflow:loss = 0.12557074, step = 4900 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1270.97
# INFO:tensorflow:loss = 0.18203115, step = 5000 (0.079 sec)
# INFO:tensorflow:global_step/sec: 1248.99
# INFO:tensorflow:loss = 0.12558618, step = 5100 (0.080 sec)
# INFO:tensorflow:global_step/sec: 1221.8
# INFO:tensorflow:loss = 0.21216792, step = 5200 (0.082 sec)
# INFO:tensorflow:global_step/sec: 1257.03
# INFO:tensorflow:loss = 0.10960115, step = 5300 (0.080 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5400...
# INFO:tensorflow:Saving checkpoints for 5400 into /tmp/tmpkgcln5d7/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5400...
# INFO:tensorflow:Loss for final step: 0.20239983.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T14:59:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkgcln5d7/model.ckpt-5400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.13117s
# INFO:tensorflow:Finished evaluation at 2020-06-20-14:59:58
# INFO:tensorflow:Saving dict for global step 5400: accuracy = 0.95, global_step = 5400, loss = 0.16382739
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5400: /tmp/tmpkgcln5d7/model.ckpt-5400
# {'accuracy': 0.95, 'loss': 0.16382739, 'global_step': 5400}

# %% [markdown]
# ## Resorting to non-linear regression

# %%
try:
    from tensorflow.python.keras.layers.kernelized import RandomFourierFeatures
except:
    # from TF 2.2
    from tensorflow.keras.layers.experimental import RandomFourierFeatures

# %%
def create_svc(feature_columns, feature_layer_inputs, optimizer, 
               loss='hinge', metrics=['accuracy'],
               l2=0.01, output_dim=64, scale=None):
    
    regularizer = keras.regularizers.l2(l2)

    feature_layer = keras.layers.DenseFeatures(feature_columns)
    feature_layer_outputs = feature_layer(feature_layer_inputs)
    norm = keras.layers.BatchNormalization()(feature_layer_outputs)
    rff = RandomFourierFeatures(output_dim=output_dim, scale=scale, kernel_initializer='gaussian')(norm)
    outputs = keras.layers.Dense(1, 
                                 kernel_initializer='normal', 
                                 kernel_regularizer = regularizer, 
                                 activation='sigmoid')(rff)
    
    model = keras.Model(inputs=[v for v in feature_layer_inputs.values()], outputs=outputs)
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
categorical_cols = []
numeric_cols = ['clump_thickness', 'cell_size_uniformity', 'cell_shape_uniformity',
                'marginal_adhesion', 'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin',
                'normal_nucleoli', 'mitoses']

feature_columns, feature_layer_inputs = define_feature_columns_layers(data, categorical_cols, numeric_cols)

optimizer = keras.optimizers.Adam(learning_rate=0.00005)
model = create_svc(feature_columns, feature_layer_inputs, optimizer, 
                   loss='hinge', l2=0.001, output_dim=512)

estimator = canned_keras(model)

train_input_fn = make_input_fn(train, y_train, num_epochs=500, batch_size=512)
test_input_fn = make_input_fn(test, y_test, num_epochs=1, shuffle=False)

estimator.train(train_input_fn)
result = estimator.evaluate(test_input_fn)

print(result)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:From /home/lm/anaconda3/envs/kaggle/lib/python3.6/site-packages/tensorflow/python/keras/layers/kernelized.py:187: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp5dm2hlb2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/tmp/tmp5dm2hlb2/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: /tmp/tmp5dm2hlb2/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 5 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp5dm2hlb2/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.1502455, step = 0
# INFO:tensorflow:global_step/sec: 328.236
# INFO:tensorflow:loss = 0.98032916, step = 100 (0.305 sec)
# INFO:tensorflow:global_step/sec: 387.402
# INFO:tensorflow:loss = 0.9104859, step = 200 (0.258 sec)
# INFO:tensorflow:global_step/sec: 379.54
# INFO:tensorflow:loss = 0.881327, step = 300 (0.264 sec)
# INFO:tensorflow:global_step/sec: 379.107
# INFO:tensorflow:loss = 0.8467352, step = 400 (0.264 sec)
# INFO:tensorflow:global_step/sec: 379.902
# INFO:tensorflow:loss = 0.8151202, step = 500 (0.263 sec)
# INFO:tensorflow:global_step/sec: 389.599
# INFO:tensorflow:loss = 0.7872509, step = 600 (0.257 sec)
# INFO:tensorflow:global_step/sec: 405.567
# INFO:tensorflow:loss = 0.7793529, step = 700 (0.247 sec)
# INFO:tensorflow:global_step/sec: 401.159
# INFO:tensorflow:loss = 0.7609031, step = 800 (0.249 sec)
# INFO:tensorflow:global_step/sec: 406.979
# INFO:tensorflow:loss = 0.75566494, step = 900 (0.246 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp5dm2hlb2/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.62947613.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T15:00:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp5dm2hlb2/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.14589s
# INFO:tensorflow:Finished evaluation at 2020-06-20-15:00:03
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.95, global_step = 1000, loss = 0.7390725
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmp5dm2hlb2/model.ckpt-1000
# {'accuracy': 0.95, 'loss': 0.7390725, 'global_step': 1000}

# %% [markdown]
# ## Preparing Wide & Deep Learning for Recommender Systems

# %%
census_dir = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/'
train_path = tf.keras.utils.get_file('adult.data', census_dir + 'adult.data')
test_path = tf.keras.utils.get_file('adult.test', census_dir + 'adult.test')

columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
           'marital_status', 'occupation', 'relationship', 'race', 'gender',
           'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
           'income_bracket']

train_data = pd.read_csv(train_path, header=None, names=columns)
test_data = pd.read_csv(test_path, header=None, names=columns, skiprows=1)

# %%
predictors = ['age', 'workclass', 'education', 'education_num',
              'marital_status', 'occupation', 'relationship', 'gender']

y_train = (train_data.income_bracket==' >50K').astype(int)
y_test = (test_data.income_bracket==' >50K.').astype(int)

train_data = train_data[predictors]
test_data = test_data[predictors]

# %%
train_data[['age', 'education_num']] = train_data[['age', 'education_num']].fillna(train_data[['age', 'education_num']].mean())
test_data[['age', 'education_num']] = test_data[['age', 'education_num']].fillna(train_data[['age', 'education_num']].mean())

# %%
def define_feature_columns(data_df, numeric_cols, categorical_cols, categorical_embeds, dimension=30):
    numeric_columns = []
    categorical_columns = []
    embeddings = []
    
    for feature_name in numeric_cols:
        numeric_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))
    
    for feature_name in categorical_cols:
        vocabulary = data_df[feature_name].unique()
        categorical_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))
        
    for feature_name in categorical_embeds:
        vocabulary = data_df[feature_name].unique()
        to_categorical = tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary)
        embeddings.append(tf.feature_column.embedding_column(to_categorical, dimension=dimension))
        
    return numeric_columns, categorical_columns, embeddings

def create_interactions(interactions_list, buckets=10):
    feature_columns = []
    
    for (a, b) in interactions_list:
        crossed_feature = tf.feature_column.crossed_column([a, b], hash_bucket_size=buckets)
        crossed_feature_one_hot = tf.feature_column.indicator_column(crossed_feature)
        feature_columns.append(crossed_feature_one_hot)
        
    return feature_columns

# %%
numeric_columns, categorical_columns, embeddings = define_feature_columns(train_data, 
                                                                          numeric_cols=['age', 'education_num'], 
                                                                          categorical_cols=['gender'], 
                                                                          categorical_embeds=['workclass', 'education',
                                                                                              'marital_status', 'occupation', 
                                                                                              'relationship'], 
                                                                          dimension=32)

interactions = create_interactions([['education', 'occupation']], buckets=10)

# %%
estimator = tf.estimator.DNNLinearCombinedClassifier(
    # wide settings
    linear_feature_columns=numeric_columns+categorical_columns+interactions,
    linear_optimizer=keras.optimizers.Ftrl(learning_rate=0.0002),
    # deep settings
    dnn_feature_columns=embeddings,
    dnn_hidden_units=[1024, 256, 128, 64],
    dnn_optimizer=keras.optimizers.Adam(learning_rate=0.0001))
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpcitgqcf4
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpcitgqcf4', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=256):
    
    def input_function():
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))
        if shuffle:
            ds = ds.shuffle(1000)
        ds = ds.batch(batch_size).repeat(num_epochs)
        return ds
    
    return input_function

# %%
train_input_fn = make_input_fn(train_data, y_train, num_epochs=100, batch_size=256)
test_input_fn = make_input_fn(test_data, y_test, num_epochs=1, shuffle=False)

# %%
estimator.train(input_fn=train_input_fn, steps=1500)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpcitgqcf4/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.69487995, step = 0
# INFO:tensorflow:global_step/sec: 80.448
# INFO:tensorflow:loss = 0.3136022, step = 100 (1.244 sec)
# INFO:tensorflow:global_step/sec: 109.368
# INFO:tensorflow:loss = 0.3374385, step = 200 (0.914 sec)
# INFO:tensorflow:global_step/sec: 107.546
# INFO:tensorflow:loss = 0.35022599, step = 300 (0.930 sec)
# INFO:tensorflow:global_step/sec: 109.832
# INFO:tensorflow:loss = 0.3588723, step = 400 (0.910 sec)
# INFO:tensorflow:global_step/sec: 104.885
# INFO:tensorflow:loss = 0.41374043, step = 500 (0.953 sec)
# INFO:tensorflow:global_step/sec: 111.168
# INFO:tensorflow:loss = 0.3219393, step = 600 (0.899 sec)
# INFO:tensorflow:global_step/sec: 111.116
# INFO:tensorflow:loss = 0.40868202, step = 700 (0.900 sec)
# INFO:tensorflow:global_step/sec: 108.174
# INFO:tensorflow:loss = 0.40446743, step = 800 (0.924 sec)
# INFO:tensorflow:global_step/sec: 105.882
# INFO:tensorflow:loss = 0.3431934, step = 900 (0.945 sec)
# INFO:tensorflow:global_step/sec: 107.369
# INFO:tensorflow:loss = 0.37274846, step = 1000 (0.931 sec)
# INFO:tensorflow:global_step/sec: 110.167
# INFO:tensorflow:loss = 0.32524717, step = 1100 (0.908 sec)
# INFO:tensorflow:global_step/sec: 109.971
# INFO:tensorflow:loss = 0.41662997, step = 1200 (0.909 sec)
# INFO:tensorflow:global_step/sec: 107.117
# INFO:tensorflow:loss = 0.31098923, step = 1300 (0.934 sec)
# INFO:tensorflow:global_step/sec: 97.1527
# INFO:tensorflow:loss = 0.31715584, step = 1400 (1.029 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1500...
# INFO:tensorflow:Saving checkpoints for 1500 into /tmp/tmpcitgqcf4/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1500...
# INFO:tensorflow:Loss for final step: 0.32271147.

# %%
results = estimator.evaluate(input_fn=test_input_fn)
print(results)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-06-20T15:00:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpcitgqcf4/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.52489s
# INFO:tensorflow:Finished evaluation at 2020-06-20-15:00:29
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.83367115, accuracy_baseline = 0.76377374, auc = 0.8782741, auc_precision_recall = 0.68388885, average_loss = 0.35881108, global_step = 1500, label/mean = 0.23622628, loss = 0.3589277, precision = 0.69702214, prediction/mean = 0.22744568, recall = 0.52340096
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: /tmp/tmpcitgqcf4/model.ckpt-1500
# {'accuracy': 0.83367115, 'accuracy_baseline': 0.76377374, 'auc': 0.8782741, 'auc_precision_recall': 0.68388885, 'average_loss': 0.35881108, 'label/mean': 0.23622628, 'loss': 0.3589277, 'precision': 0.69702214, 'prediction/mean': 0.22744568, 'recall': 0.52340096, 'global_step': 1500}

# %%
def predict_proba(predictor):
    preds = list()
    for pred in predictor:
        preds.append(pred['probabilities'])
    return np.array(preds)

predictions = predict_proba(estimator.predict(input_fn=test_input_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpcitgqcf4/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# array([[0.99865156, 0.00134846],
#        [0.8887447 , 0.1112553 ],
#        [0.35291824, 0.64708173],
#        ...,
#        [0.2693475 , 0.7306526 ],
#        [0.942907  , 0.05709296],
#        [0.19055176, 0.8094482 ]], dtype=float32)
